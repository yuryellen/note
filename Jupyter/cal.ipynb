# %%
8100/576
# Out:
# 14.0625

# %%
(198+233)/(18+18)
# Out:
# 11.972222222222221

# %%
r1 = (119.5+127.5)/(17+17)  # 变量赋值会抑制隐式输出
r2 = (134+165)/(11+18)
r3 = (284.5+147)/(17+16)
f"{r1:.1f}, {r2:.1f}, {r3:.1f}, {r4:.1f}"
# Out:
# '7.3, 10.3, 13.1, 13.7'
